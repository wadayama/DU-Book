# %% [markdown]
# ## RBFによる関数近似
#
# Copyright (c) 2022 Tadashi Wadayama
# Released under the MIT license
# https://opensource.org/licenses/mit-license.php

# %%
using LinearAlgebra
using Plots
gr()
using Random
Random.seed!(1)
using Flux

# %%
δ = 0.05
β = 20.0
# Out:
# 20.0

# %%
function rbf_func(x, θ)
    rbf(x, β) = exp(-β*x^2)
    s = 0.0
    for i in 1:length(θ)
        s += θ[i]*rbf(x - δ*(i-1)+0.5, β)
    end
    return s
end
# Out:
# rbf_func (generic function with 1 method)

# %%
i=1
rbf(x, β) = exp(-β*x^2)
p1 = plot(x->rbf(x - δ*(i-1)+0.5, β), color=:black)
for i in 1:50
    plot!(x->rbf(x - δ*(i-1)+0.5, β), color=:black)
end
plot(p1, xlims=[-1,2.5], legend=false)

# %%
savefig("rbf_shape.pdf")

# %%
function Fit(T, N, θ)
    dx = T/N
    J = 0.0
    for i in 1:N
        u = rbf_func(i*dx, θ)      
        f = exp(-5*i*dx)*sin(5*i*dx)
        J += (u - f)^2
    end
    return J
end
# Out:
# Fit (generic function with 1 method)

# %% [markdown]
# ## 学習過程

# %%
N = 100
T = 1.0
opt = ADAM(1.0) 
θ_train = ones(50)
train_itr = 250

function train(T, N, θ)
    ps = Flux.params(θ)
    for i in 1:train_itr
        gs = gradient(ps) do
            Fit(T, N, θ)
        end
        Flux.Optimise.update!(opt, ps, gs)
        println(Fit(T, N, θ))
    end
end
# Out:
# train (generic function with 2 methods)

# %%
train(T, N, θ_train)
# Out:
# 2.4997578471958857
# 2845.7194053544927
# 3390.9065418428304
# 1407.2097950870061
# 52.02235742724382
# 468.8533236227985
# 1518.1663475754842
# 1704.4774130892426
# 969.6187185454039
# 183.37299100209358
# 38.08400969821741
# 479.4744380618602
# 894.9071849075933
# 833.9267830002452
# 409.5848850755628
# 50.71627585508385
# 46.55057749441282
# 305.85350224532505
# 501.6293841100514
# 430.2042811513776
# 185.55934525815238
# 12.04782495904644
# 46.314676320184574
# 201.4467776936629
# 285.72670925037136
# 212.25888899952997
# 68.77975461300782
# 0.0828802368349175
# 52.64598070040724
# 141.165305825307
# 157.27335026336868
# 87.7487505737868
# 13.223807595283159
# 7.3223352337254655
# 58.27013698008673
# 94.40991559238056
# 72.67958477050931
# 22.195950193435376
# 0.13309123454310418
# 22.549624165704625
# 52.182973553513655
# 49.818025808188104
# 20.48554834177609
# 0.5193928244411755
# 9.422003294437088
# 29.032556085595395
# 31.402948597439913
# 14.540209315003327
# 0.721508321222973
# 4.922922131274749
# 17.16716586316831
# 19.089604659726877
# 8.71205250426416
# 0.3464805127462456
# 3.4169088160946495
# 10.915281226988956
# 11.26298489389939
# 4.414999183564953
# 0.04368664963246289
# 2.9262909425182397
# 7.247318561889568
# 6.265098828131443
# 1.7411060210772216
# 0.10179703032696874
# 2.699853802101407
# 4.740078533402197
# 3.071084347947165
# 0.3990474470254988
# 0.43781746866298
# 2.382276392679575
# 2.8234751538421485
# 1.1584181799035753
# 0.006059731962497405
# 0.7953876096541178
# 1.837582979565262
# 1.3737597230704655
# 0.2316972926681397
# 0.13568747493102457
# 0.9297801358476367
# 1.1335031271950529
# 0.44381415948024194
# 0.0028706056913469506
# 0.3741140017408268
# 0.7588825350473226
# 0.4843334145084425
# 0.04486586571473558
# 0.11579208621266819
# 0.4430830174703446
# 0.4103984211863324
# 0.09549337839963684
# 0.024176068374669235
# 0.2357976644721351
# 0.30237487302752997
# 0.11324890532353289
# 0.0029586653678953232
# 0.11827443157015562
# 0.20547596145993563
# 0.10485211459503987
# 0.0032323940889502603
# 0.05769497822124855
# 0.13364514005644898
# 0.08497782973461979
# 0.00637271220274584
# 0.028375028744119575
# 0.08540879519006822
# 0.06362789537744062
# 0.007634897568640055
# 0.01472027206523166
# 0.05468064208631848
# 0.04531551910166309
# 0.0070094276782184575
# 0.008459130580566498
# 0.03557260577184566
# 0.03122096452508741
# 0.005482997010047181
# 0.005570483529436222
# 0.02372200184134026
# 0.021001413583905736
# 0.003840647783512624
# 0.004196943189105089
# 0.0162560703263848
# 0.013843098861883847
# 0.0024903996032150993
# 0.00350513137943883
# 0.011408253156602809
# 0.008939663954540942
# 0.0015637041277087016
# 0.003115261475341177
# 0.008130220124750764
# 0.005640753597675225
# 0.0010353597160992815
# 0.002844779777409597
# 0.005819724413140299
# 0.0034732080475864666
# 0.0008142463256749053
# 0.002600210460163601
# 0.004137392534247556
# 0.0021030592416388166
# 0.0007907673542807597
# 0.002334325590735347
# 0.0028947691781067686
# 0.0012929324241979633
# 0.0008637868853360484
# 0.0020326702232631244
# 0.001987894819670367
# 0.0008676983078352776
# 0.0009528316642008632
# 0.0017044392028526692
# 0.00135378343999295
# 0.0006911759687102207
# 0.0010046101472084778
# 0.0013753542998862405
# 0.0009448818497309878
# 0.0006552096600759777
# 0.0009948914855877357
# 0.001077577638190208
# 0.0007142057247449706
# 0.0006765987760172688
# 0.0009257618895893743
# 0.000838895466087263
# 0.0006106642837146236
# 0.0006989021155711434
# 0.0008186833402096453
# 0.0006739025083023362
# 0.0005819366151878447
# 0.0006933128151597017
# 0.0007032566043885218
# 0.0005796980923147678
# 0.0005820626814908436
# 0.0006558271736545127
# 0.0006054497363848909
# 0.0005382846246217712
# 0.0005793793977889609
# 0.0005992081847369092
# 0.0005388641281391827
# 0.0005244589368299854
# 0.0005603632638409421
# 0.0005417405285498561
# 0.000502415761396487
# 0.0005158248867451703
# 0.0005272329588180811
# 0.0004969553591732843
# 0.000484707230112048
# 0.000499986085256892
# 0.0004902507516081873
# 0.00046840259574974005
# 0.00047220340101721377
# 0.00047581096202715934
# 0.00045891577486783516
# 0.0004510389198946109
# 0.000456372628969363
# 0.00044898017295548975
# 0.00043656103720158445
# 0.0004369644808160145
# 0.00043603356888066903
# 0.0004254446704018723
# 0.000420505306110806
# 0.000421067339515852
# 0.0004146653484507636
# 0.00040718465843483405
# 0.00040606123353988506
# 0.0004029614006666846
# 0.0003957718103315755
# 0.00039231798132076525
# 0.00039051777577825533
# 0.00038499185675307257
# 0.00038010117296826253
# 0.00037805549193602514
# 0.0003741742032213575
# 0.0003690329387674817
# 0.00036615342324080853
# 0.0003632361002679482
# 0.00035860756486559656
# 0.0003550253575004386
# 0.00035238305619553933
# 0.00034848538750394185
# 0.00034460746804623716
# 0.0003418413786155093
# 0.00033854207998502365
# 0.00033473130521755615
# 0.0003317382429740444
# 0.00032879218572912984
# 0.00032524516572417776
# 0.00032209728791818965
# 0.0003192980058113705
# 0.0003160584009682886
# 0.000312881599825041
# 0.0003101135399119549
# 0.00030713609003355847
# 0.0003040361028655207
# 0.00030126495293434887
# 0.00029847636280679133
# 0.00029551268044526204
# 0.00029275269537655367
# 0.00029008919386973634
# 0.0002872791641354026
# 0.000284561901423419
# 0.00028198324093311013
# 0.00027931801989925496
# 0.00027667245105662656
# 0.0002741606198062141
# 0.0002716209659643774
# 0.0002690654343241243
# 0.00026661702476576536
# 0.0002641836399805474
# 0.00026172569595837603
# 0.0002593440912733569
# 0.0002570021346953594
# 0.0002546417223842162
# 0.0002523317855653095

# %%
scatter(x->rbf_func(x, θ_train),  lw=1, xlims=[0,1],label="RBF", xlabel="x",color=:black, marker=:+)
plot!(x->exp(-5*x)*sin(5*x), lw=1, label="Exact",color=:black, ls=:dot)

# %%
savefig("rbf.pdf")
