# %% [markdown]
# # DU-GD法 (二次関数)
#
# Copyright (c) 2022 Tadashi Wadayama
# Released under the MIT license
# https://opensource.org/licenses/mit-license.php

# %%
using LinearAlgebra
using Plots
gr()
using Random
Random.seed!(1)
using Flux

# %% [markdown]
# ### 準備 (グローバル定数の設定)

# %%
n = 100
num_itr = 30
train_itr = 25
K = 50
adam_lr = 1e-3
max_inner = 20
# Out:
# 20

# %%
A = diagm(1:n)
λmin = 1
λmax = n
ηopt = 2/(λmin + λmax)
# Out:
# 0.019801980198019802

# %% [markdown]
# ### 固定ステップサイズのGD法の二乗誤差

# %%
function GD(max_itr, x0)
    x = x0
    for i in 1:max_itr
        x = x - ηopt*A*x
    end
    return x
end

function comp_se(max_itr,x0)
    x̂ = GD(max_itr, x0)
    return norm(x̂)^2
end

xinit = randn(n)
GD_mse = [comp_se(i,xinit) for i in 1:num_itr]
plot(1:num_itr, GD_mse, lw=1, yscale=:log10, label="GD (fixed step size)", color=:black,  xlabel="Iteration", ylabel="Squared error")

# %% [markdown]
# ### DU-GD反復の定義

# %%
function DU_GD(max_itr, x0, η, T)
    x = x0
    for i in 0:max_itr-1
        k = (i % T)+1
        x = x - η[k]*A*x
    end
    return x
end
# Out:
# DU_GD (generic function with 1 method)

# %% [markdown]
# ### 損失関数の定義

# %%
function loss(x̂)
    return norm(x̂)^2/K
end
# Out:
# loss (generic function with 1 method)

# %% [markdown]
# ### 訓練関数の定義

# %%
function train(opt, η, T, train_itr)
    ps = Flux.params(η) 
    for itr in 1:train_itr
        for i in 1:max_inner
            x0 = randn(n,K)
            gs = Flux.gradient(ps) do
                x_est = DU_GD(itr, x0, η, T)
                loss(x_est)
            end
            Flux.Optimise.update!(opt, ps, gs)
        end
        x0 = randn(n,K)
        x_est = DU_GD(itr, x0, η, T)
        println(itr, " ", loss(x_est))
    end
end
# Out:
# train (generic function with 1 method)

# %% [markdown]
# ### DU-GDの誤差評価用関数

# %%
function comp_se_DUGD(max_itr, x0, η, T)
    x_est = DU_GD(max_itr, x0, η, T)
    return loss(x_est)
end
# Out:
# comp_se_DUGD (generic function with 1 method)

# %% [markdown]
# ### 学習過程

# %%
T = 3
η_train = zeros(num_itr) 
opt = Flux.ADAM(adam_lr) 
train(opt, η_train, T, train_itr)
DUGD_mse =[comp_se_DUGD(i, xinit, η_train, T) for i in 1:num_itr]
opt_param1 = [η_train[(i%T)+1] for i in 0:num_itr-1]
plot!(1:num_itr, DUGD_mse, lw=1, label="DU-GD T="*string(T), color=:black, marker=:o)
# Out:
# 1 24.867542933653382
# 2 13.30034385952254
# 3 8.977235754242688
# 4 5.592862605810333
# 5 4.059750514135551
# 6 2.60897312705534
# 7 2.341578327132694
# 8 2.0785820659259575
# 9 1.524604517750336
# 10 1.3213196388540223
# 11 1.3165943490820007
# 12 1.0493300609829521
# 13 1.0443719600010528
# 14 0.7125074476509422
# 15 0.591747078332403
# 16 0.5178475828791668
# 17 0.6544408610613516
# 18 0.4389276257101362
# 19 0.3851370732784228
# 20 0.3485696352596949
# 21 0.22783414553090822
# 22 0.3468457824736448
# 23 0.2175310061817844
# 24 0.24053365113687458
# 25 0.15370913110441248

# %%
savefig("DU-GD-Quadratic.pdf")
# Out:
# "/Users/wadayama/Dropbox/DU-Book_test/Chapter_3/DU-GD-Quadratic.pdf"

# %% [markdown]
# ### 最適パラメータのプロット

# %%
plot(1:num_itr, opt_param1, lw=1, label="T=3", color=:black, ls=:solid, xlabel="Iteration")
plot!(1:num_itr, x->ηopt, lw=1, label="ηopt", color=:black, ls=:dash)

# %%
savefig("DU-GD-Quadratic-param.pdf")
# Out:
# "/Users/wadayama/Dropbox/DU-Book_test/Chapter_3/DU-GD-Quadratic-param.pdf"
