# %% [markdown]
# # DU-GD法 (最小二乗問題)
#
# 周期性条件なし
#
# Copyright (c) 2022 Tadashi Wadayama
# Released under the MIT license
# https://opensource.org/licenses/mit-license.php

# %%
using LinearAlgebra
using Plots
gr()
using Random
Random.seed!(1)
using Flux

# %% [markdown]
# ### 準備 (グローバル定数の設定)

# %%
n = 50　
m = 100　
num_itr = 50
K = 100 
adam_lr = 1e-4
max_inner = 40

A = randn(m,n)
Pinv = (A'*A)^(-1)*A'
eig = eigvals(A'*A)
λmin = minimum(eig)
λmax = maximum(eig)
ηopt = 2/(λmin + λmax)
# Out:
# 0.006832155976129672

# %% [markdown]
# ### ミニバッチ生成関数

# %%
function mini_batch(K)
    y = randn(m,K)
    x_opt = Pinv*y
    return y, x_opt
end
# Out:
# mini_batch (generic function with 1 method)

# %% [markdown]
# ### 固定ステップサイズのGD法のMSE

# %%
function GD(max_itr, y)
    x = zeros(n, K)
    for i in 1:max_itr
        x = x - ηopt*A'*(A*x - y)
    end
    return x
end

function comp_mse(max_itr)
    y, x_opt = mini_batch(K)
    x̂ = GD(max_itr, y)
    return norm(x_opt - x̂)^2/K
end
        
GD_mse = [comp_mse(i) for i in 1:num_itr]
plot(1:num_itr, GD_mse, lw=1, yscale=:log10, label="GD (fixed step size)", color=:black,  xlabel="Iteration", ylabel="Mean squared error")

# %% [markdown]
# ### DU-GD反復の定義

# %%
function DU_GD(max_itr, y, η)
    x = zeros(n, K)
    for i in 1:max_itr
        x = x - η[i]*A'*(A*x - y)
    end
    return x
end
# Out:
# DU_GD (generic function with 1 method)

# %% [markdown]
# ### 損失関数の定義

# %%
function loss(x_opt, x̂)
    return norm(x_opt - x̂)^2/K
end
# Out:
# loss (generic function with 1 method)

# %% [markdown]
# ### 訓練関数の定義

# %%
function train(opt, η)
    ps = params(η) 
    for itr in 1:num_itr
        for i in 1:max_inner
            y, x_opt = mini_batch(K)
            gs = gradient(ps) do
                x̂ = DU_GD(itr, y, η)
                loss(x_opt, x̂)
            end
            Flux.Optimise.update!(opt, ps, gs)
        end
        y, x_opt = mini_batch(K)
        x_est = DU_GD(itr, y, η)
        println(itr, " ", loss(x_opt, x_est))
    end
end
# Out:
# train (generic function with 1 method)

# %% [markdown]
# ### DU-GDのMSE評価用関数

# %%
function comp_mse_DUGD(max_itr, η)
    y, x_opt = mini_batch(K)
    x̂ = DU_GD(max_itr, y, η)
    return loss(x_opt, x̂)
end
# Out:
# comp_mse_DUGD (generic function with 1 method)

# %% [markdown]
# ### 学習過程

# %%
η_train = zeros(num_itr) 
opt = ADAM(adam_lr) 
train(opt, η_train)
DUGD_mse =[comp_mse_DUGD(i, η_train) for i in 1:num_itr]
plot!(1:num_itr, DUGD_mse, lw=1, label="DU-GD", color=:black, marker=:o)
# Out:
# 1 0.7214523434243655
# 2 0.395555603130836
# 3 0.2600516101268676
# 4 0.16818043637728433
# 5 0.1137530049923768
# 6 0.07349067386014776
# 7 0.050345783875454304
# 8 0.03441434855154423
# 9 0.023459148164336162
# 10 0.016304495229730386
# 11 0.00915684748255141
# 12 0.007007058958444897
# 13 0.0040512085013496854
# 14 0.0043324257356546
# 15 0.0032425922540887174
# 16 0.0016044970676195628
# 17 0.0011142138468885553
# 18 0.0005982913627141299
# 19 0.0003725912098377181
# 20 0.00024417256845875605
# 21 0.00017034187766032125
# 22 0.00010758183811724277
# 23 6.860899810838139e-5
# 24 8.046115877017115e-5
# 25 5.157157497522583e-5
# 26 2.7805242216579085e-5
# 27 1.5092816202995863e-5
# 28 8.132178364932547e-6
# 29 4.827329012802121e-6
# 30 3.0144986520022996e-6
# 31 1.6379791783468323e-6
# 32 9.666915156925018e-7
# 33 6.281437742078205e-7
# 34 4.801180744358381e-7
# 35 2.540297032851624e-7
# 36 8.105963698517973e-7
# 37 4.6303138592937316e-7
# 38 3.364274916343309e-7
# 39 1.829219134603344e-7
# 40 1.1381067807424818e-7
# 41 5.880166604452787e-8
# 42 3.038917942285833e-8
# 43 2.718410752666045e-8
# 44 4.4097118559499076e-8
# 45 1.9859387362728516e-8
# 46 1.4822326553190533e-8
# 47 9.994309593545718e-9
# 48 6.5615585219619995e-9
# 49 3.6383333168292605e-9
# 50 3.0805204648483856e-9

# %%
savefig("DU-GD-LMS2.pdf")

# %% [markdown]
# ### 最適パラメータのプロット

# %%
plot(1:num_itr, η_train, lw=1, label="T=2", color=:black, ls=:dash, xlabel="Iteration")

# %%
savefig("DU-GD-LMS2-param.pdf")
