# %% [markdown]
# # DU-NoisyGD法 (最小二乗問題)
#
# Copyright (c) 2022 Tadashi Wadayama
# Released under the MIT license
# https://opensource.org/licenses/mit-license.php

# %%
using LinearAlgebra
using Plots
gr()
using Random
Random.seed!(1)
using Flux

# %% [markdown]
# ### 準備 (グローバル定数の設定)

# %%
n = 50
m = 100
num_itr = 100
K = 200
adam_lr = 5e-6
max_inner = 50
std = 1.0

A = randn(m,n)
Pinv = (A'*A)^(-1)*A'
eig = eigvals(A'*A)
λmin = minimum(eig)
λmax = maximum(eig)
ηopt = 2/(λmin + λmax)
# Out:
# 0.006832155976129673

# %% [markdown]
# ### ミニバッチ生成関数

# %%
function mini_batch(K)
    y = randn(m,K)
    x_opt = Pinv*y
    return y, x_opt
end
# Out:
# mini_batch (generic function with 1 method)

# %% [markdown]
# ### 固定ステップサイズのGD法のMSE (勾配雑音あり)

# %%
function GD(max_itr, y)
    x = zeros(n, K)
    for i in 1:max_itr
        x = x - ηopt*(A'*(A*x - y) + std*randn(n,K))
    end
    return return x
end

function comp_mse(max_itr) 
    y, x_opt = mini_batch(K)
    x̂ = GD(max_itr, y)
    return norm(x_opt - x̂)^2/K
end
        
GD_mse = [comp_mse(i) for i in 1:num_itr]
plot(1:num_itr, GD_mse, lw=1, yscale=:log10, label="NoisyGD (fixed step size)", color=:black,  xlabel="Iteration", ylabel="Mean squared error")

# %% [markdown]
# ### DU-GD反復の定義

# %%
function DU_GD(max_itr, y, η)
    x = zeros(n, K)
    for i in 0:max_itr-1
        x = x - η[i+1]*(A'*(A*x - y) + std*randn(n,K))
    end
    return x
end
# Out:
# DU_GD (generic function with 1 method)

# %% [markdown]
# ### 損失関数の定義

# %%
function loss(x_opt, x̂)
    return norm(x_opt - x̂)^2/K
end
# Out:
# loss (generic function with 1 method)

# %% [markdown]
# ### 訓練関数の定義

# %%
function train(opt, η)
    ps = params(η) 
    for itr in 1:num_itr 
        for i in 1:max_inner 
            y, x_opt = mini_batch(K)
            gs = gradient(ps) do
                x̂ = DU_GD(itr, y, η)
                loss(x_opt, x̂)
            end
            Flux.Optimise.update!(opt, ps, gs) 
        end
        y, x_opt = mini_batch(K)
        x̂ = DU_GD(itr, y, η)
        println(itr, " ", loss(x_opt, x̂))
    end
end
# Out:
# train (generic function with 1 method)

# %% [markdown]
# ### DU-GDのMSE評価用関数

# %%
function comp_mse_DUGD(max_itr, η)
    y, x_opt = mini_batch(K)
    x̂ = DU_GD(max_itr, y, η)
    return loss(x_opt, x̂)
end
# Out:
# comp_mse_DUGD (generic function with 1 method)

# %% [markdown]
# ### 学習過程

# %%
η_train = zeros(num_itr) 
opt = ADAM(adam_lr) 
train(opt, η_train)
DUGD_mse =[comp_mse_DUGD(i, η_train) for i in 1:num_itr]
plot!(1:num_itr, DUGD_mse, lw=1, label="DU-NoisyGD", color=:black, marker=:+, yscale=:log10)
# Out:
# 1 0.9685175680473556
# 2 0.9193033634197916
# 3 0.8130925268114355
# 4 0.7520150914980693
# 5 0.6696567237704844
# 6 0.5479375554972501
# 7 0.525875260918158
# 8 0.462376499477102
# 9 0.38618108511722077
# 10 0.35510867832603027
# 11 0.3177404850528544
# 12 0.258998842690105
# 13 0.23890953207931329
# 14 0.20434088046867224
# 15 0.17886611931056864
# 16 0.15471632131829632
# 17 0.1340756714135849
# 18 0.11365657596856511
# 19 0.10428022766729925
# 20 0.0853259577809122
# 21 0.07772300406535439
# 22 0.06669750850974139
# 23 0.05643154598073538
# 24 0.04960430759356056
# 25 0.047301046018348225
# 26 0.04039567092915616
# 27 0.037154870431282246
# 28 0.030849860107462115
# 29 0.02963744927529314
# 30 0.02280659052918799
# 31 0.021029765972190605
# 32 0.018715622887007368
# 33 0.017463637164054423
# 34 0.012929883065103637
# 35 0.01320875326798693
# 36 0.010659694048330797
# 37 0.010848757816672404
# 38 0.008736728464909397
# 39 0.008292701034135085
# 40 0.007204840262672156
# 41 0.006112022085045829
# 42 0.005808384102487728
# 43 0.005860754161711002
# 44 0.005061989759773416
# 45 0.005386060730859891
# 46 0.004186316685441023
# 47 0.004018644459090497
# 48 0.0037517300333419863
# 49 0.003486249525298776
# 50 0.003269011157319021
# 51 0.0029313056338079336
# 52 0.0028378429871639033
# 53 0.002706801229776396
# 54 0.0027681868884451744
# 55 0.002610972364408512
# 56 0.002072476644321565
# 57 0.0023443987330884703
# 58 0.002178562132228535
# 59 0.0021555257684693603
# 60 0.002082115666296376
# 61 0.0017055914278569304
# 62 0.0019311847531997767
# 63 0.00167584087003809
# 64 0.0016067964825120214
# 65 0.0015005064961960165
# 66 0.0016340419690737424
# 67 0.0014789478783606219
# 68 0.0015492438111478618
# 69 0.001435377086891661
# 70 0.0014132130930233585
# 71 0.001239711039208038
# 72 0.0013478120386896458
# 73 0.001190944857227261
# 74 0.0012432629069510732
# 75 0.0011919272075217955
# 76 0.0011796166699557895
# 77 0.0011359771263497517
# 78 0.0010686326527725868
# 79 0.0010474814309733445
# 80 0.0010443976424960087
# 81 0.00102297818804252
# 82 0.001015966875095027
# 83 0.000986758982054491
# 84 0.0009960028491845482
# 85 0.0009559777442654162
# 86 0.0009895643058354566
# 87 0.0009511380730367654
# 88 0.0008845832073322442
# 89 0.0008900000807514902
# 90 0.0008751637885130624
# 91 0.0008689819437424234
# 92 0.0008271143537449428
# 93 0.0008657075300270932
# 94 0.0008306924496991709
# 95 0.0007677867788118671
# 96 0.0007323794086567555
# 97 0.0007761767065874803
# 98 0.0007527373207485695
# 99 0.0007439801959740473
# 100 0.0006953607135016423

# %%
savefig("DU-NoisyGD.pdf")

# %%
plot(1:num_itr, η_train, color=:black, xlabel="Iteration", legend=false)

# %%
savefig("DU-NisyGD-param.pdf")
