# %% [markdown]
# # 平均合意プロトコルにおける収束加速
#
# Copyright (c) 2022 Tadashi Wadayama
# Released under the MIT license
# https://opensource.org/licenses/mit-license.php

# %%
using LinearAlgebra
using Plots
gr()
using Random
Random.seed!(1)
using Flux
using LightGraphs
using GraphPlot
using Cairo, Compose

# %% [markdown]
# ### 準備 (グローバル定数の設定)
#
# この例ではKarateグラフを例として利用する。

# %%
n = 34
g = smallgraph("karate")
L = Matrix(laplacian_matrix(g)) + 1e-12*I 
eig = eigvals(L)
lmin = eig[2]
lmax = eig[n]
η_opt = 2.0/(lmin + lmax)

K = 200
num_itr = 75
adam_lr = 5e-4
max_inner = 50

gplot(g, nodefillc="black")
# Out:
# Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Context(BBox{l,t,r,b,w,h = 0.0w,0.0h, 1.0w,1.0h, 1.0w,1.0h}, nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.43826867157265326cx, 0.33953738154243873cy), (0.26362199649246326cx, 0.7339874846634427cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.41340817332514446cx, 0.3078064505431978cy), (0.05194004921029173cx, 0.3717883205183322cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.4528893885616619cx, 0.34312074859170794cy), (0.44203458025999737cx, 0.5128026884407987cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.4867710505498982cx, 0.2708673905994105cy), (0.8570601704761319cx, -0.0794674206497416cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.4618737657415756cx, 0.2579164959951341cy), (0.5614857887630434cx, -0.41842467327682875cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.46847328245907216cx, 0.25942883552016865cy), (0.6799723470779401cx, -0.41399617590979093cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.44805209560994325cx, 0.34253383496218454cy), (0.3873874449891241cx, 0.6805205664112594cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.4150037283894031cx, 0.3140456649239852cy), (-0.09904530979730147cx, 0.48756125716197396cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.4788426255139451cx, 0.2642884650944152cy), (0.731955995185507cx, -0.12869336398452164cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(0.49824741504571346cx, 0.3049915748165904cy), (0.9573791339777762cx, 0.3551698360667064cy)])  …  Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.21589418237315078cx, -0.06070536171999888cy), (-0.4627850258347756cx, 0.3012013426590846cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.27003800269248696cx, 0.4179373912597869cy), (-0.11204185648708799cx, 0.18238009258268562cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.33059214492073496cx, 0.4313307082809604cy), (-0.45027558330604456cx, 0.3588329110757604cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.7209705283537962cx, 0.09576701436249335cy), (-0.5735490281874499cx, 0.3610680389517489cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.7128420055206146cx, 0.08991119461718683cy), (-0.5159007466356502cx, 0.30499789672740546cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.2988857943322236cx, 0.7459425104254336cy), (-0.5274289438771024cx, 0.4331632953952649cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.2921628251732403cx, 0.7419170020524942cy), (-0.46837510865110443cx, 0.37526284179855424cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.12585394222044521cx, 0.16720201206068774cy), (-0.5150289854597485cx, 0.37811649292478033cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.12687094372483318cx, 0.16520227181136282cy), (-0.4482351795703793cx, 0.3181902712044553cy)]), Compose.LinePrimitive{Tuple{Measure, Measure}}(Tuple{Measure, Measure}[(-0.5215068375842854cx, 0.3691559066011014cy), (-0.5181639591431129cx, 0.3660087338986149cy)])], Symbol(""))]), List([Compose.Property{Compose.LineWidthPrimitive}(Compose.LineWidthPrimitive[Compose.LineWidthPrimitive(0.5144957554275265mm)]), Compose.Property{Compose.FillPrimitive}(Compose.FillPrimitive[Compose.FillPrimitive(RGBA{Float64}(0.0,0.0,0.0,0.0))]), Compose.Prope ...

# %% [markdown]
# ### ミニバッチ生成関数
#
# ミニバッチ生成関数の返り値は、ノード初期値とその平均値ベクトルからなるミニバッチとなる。

# %%
function mini_batch(K)
    x0 = randn(n, K)
    r = zeros(n, K)
    c = sum(x0, dims=1)
    for j in 1:K
        r[:,j] = c[j]*ones(n)/n
    end
    return x0, r
end
# Out:
# mini_batch (generic function with 1 method)

# %% [markdown]
# ### 固定ステップサイズの平均合意プロトコル (普通のコンセンサスプロトコル)

# %%
function consensus(max_itr, x0)
    x = x0
    for i in 1:max_itr
        x = (I - η_opt*L)*x
    end
    return x
end

function comp_mse(max_itr)
    x0, c = mini_batch(K)
    x̂ = consensus(max_itr, x0)
    return norm(c-x̂)^2/K
end
# Out:
# comp_mse (generic function with 1 method)

# %% [markdown]
# ### 合意状態からの誤差(MSE)のプロット

# %%
consensus_mse = [comp_mse(i) for i in 1:num_itr]
plot(1:num_itr, consensus_mse, lw=1, yscale=:log10, label="Consensus(fixed step size)", color=:black,  xlabel="Iteration", ylabel="Mean squared error")

# %% [markdown]
# ### DU-consensus反復の定義

# %%
function DU_consensus(max_itr, x0, η)
    x = x0
    for i in 1:max_itr
        x = (I - η[i]*L)*x
    end
    return x
end
# Out:
# DU_consensus (generic function with 1 method)

# %% [markdown]
# ### 損失関数の定義

# %%
function loss(x_opt, x̂)
    return norm(x_opt - x̂)^2/K
end
# Out:
# loss (generic function with 1 method)

# %% [markdown]
# ### 訓練関数の定義

# %%
function train(opt, η)
    ps = params(η) 
    for itr in 1:num_itr
        for i in 1:max_inner
            y, x_opt = mini_batch(K)
            gs = gradient(ps) do
                x_hat = DU_consensus(itr, y, η)
                loss(x_opt, x_hat)
            end
            Flux.Optimise.update!(opt, ps, gs) 
        end
        y, x_opt = mini_batch(K)
        x_est = DU_consensus(itr, y, η)
        println(itr, " ", loss(x_opt, x_est))
    end
end
# Out:
# train (generic function with 1 method)

# %%
function comp_mse_DU_consensus(max_itr, η)
    x0, c = mini_batch(K)
    x̂ = DU_consensus(max_itr, x0, η)
    return loss(c, x̂)
end
# Out:
# comp_mse_DU_consensus (generic function with 1 method)

# %% [markdown]
# ### 学習過程

# %%
η_train = zeros(num_itr)
opt = ADAM(adam_lr)
train(opt, η_train)
DU_consensus_mse =[comp_mse_DU_consensus(i, η_train) for i in 1:num_itr]
plot!(1:num_itr, DU_consensus_mse, lw=1, label="DU-consensus", color=:black, marker=:+)
# Out:
# 1 25.921817322153608
# 2 17.3607994216523
# 3 11.406498175465517
# 4 7.248093458623447
# 5 4.73329331884576
# 6 2.8744565344095143
# 7 2.0271022465520745
# 8 1.289152441808771
# 9 0.8201512445905411
# 10 0.704647524247285
# 11 0.5487177383002121
# 12 0.4351698777567391
# 13 0.3322574386907802
# 14 0.2585164079683762
# 15 0.20641175845135834
# 16 0.14941949410599237
# 17 0.15098498968277607
# 18 0.12345612937527699
# 19 0.09875325760777008
# 20 0.07464871222288613
# 21 0.06591964386458196
# 22 0.05957070221116949
# 23 0.04531426330204404
# 24 0.14125571122343886
# 25 0.04613995661220098
# 26 0.037860685335426046
# 27 0.027003575894004865
# 28 0.02015524418828264
# 29 0.017133779752600425
# 30 0.011777543172020928
# 31 0.01611418151223764
# 32 0.013750581302628118
# 33 0.010845774872901113
# 34 0.009872525555573745
# 35 0.006746424726520084
# 36 0.005129546398363519
# 37 0.004828391778930533
# 38 0.0036017238245357837
# 39 0.002974557050315108
# 40 0.0029978640954962587
# 41 0.002600679352520843
# 42 0.002510566758229737
# 43 0.002164298525986826
# 44 0.0012150882706441451
# 45 0.0010179621932623535
# 46 0.0010657587497844322
# 47 0.0011341398071295528
# 48 0.0008698208103414449
# 49 0.0007232115459601213
# 50 0.0006191268294576651
# 51 0.0004700117819618425
# 52 0.00042198575480129606
# 53 0.0002695174174274233
# 54 0.0002015892971202103
# 55 0.00016108060949716871
# 56 0.00012028776869997837
# 57 9.531529537012527e-5
# 58 8.994917961715965e-5
# 59 8.270860715076735e-5
# 60 5.410721785466494e-5
# 61 3.6591286880776285e-5
# 62 3.282722875008772e-5
# 63 2.771685348604763e-5
# 64 2.99023894962189e-5
# 65 2.3833623365203115e-5
# 66 2.5161586211871697e-5
# 67 7.574637812708606e-5
# 68 1.627542296990023e-5
# 69 1.2147710562811075e-5
# 70 9.675069333100082e-6
# 71 9.580246956594434e-6
# 72 5.659134715667188e-6
# 73 4.1505575596129414e-6
# 74 9.022774568557437e-5
# 75 8.006550679296668e-6

# %%
savefig("DU-consensus.pdf")

# %%
draw(PDF("karate.pdf", 8cm, 8cm), gplot(g, nodefillc="black"))
